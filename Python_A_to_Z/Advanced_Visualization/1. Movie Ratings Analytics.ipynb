# %%
import pandas as pd   #para carregar a nossa base de dados

# %%
movies = pd.read_csv('C:\\Users\\Geral\\Desktop\\Phyton Programming Course\\P4-Section6\\P4-Movie-Ratings.csv')

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns ##ter hábito de fazer estes checks
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre','CriticRating','AudienceRating', \
                  'BudgetMillions','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
#converter variáveis para categorical variables

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %% [markdown]
# ---

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Jointplots

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', kind='hex')

# %% [markdown]
# ---

# %%
#Histograms

# %%
#already know this method:

m1 = sns.distplot(movies.AudienceRating, bins=15)

# %%
m2 = sns.distplot(movies.CriticRating, bins=15)

# %%
n1 = plt.hist(movies.AudienceRating, bins=15)

# %%
sns.set_style('darkgrid')
m2 = sns.distplot(movies.CriticRating, bins=15)

# %% [markdown]
# ---

# %%
#Staked Histograms

# %%
plt.hist(movies.BudgetMillions, bins=15)
plt.show()

# %%
#Budget Millions for Drama movies - solution: Filter the data frame

movies[movies.Genre == 'Drama']
# Out:
#                     Film  Genre  CriticRating  AudienceRating  BudgetMillions  \
# 10            88 Minutes  Drama             5              51              30
# 11    A Dangerous Method  Drama            79              89              20
# 13        A Serious Man   Drama            89              64               7
# 18          Albert Nobbs  Drama            53              43               8
# 23       All Good Things  Drama            33              64              20
# ..                   ...    ...           ...             ...             ...
# 529            War Horse  Drama            77              73              66
# 532  Water For Elephants  Drama            60              72              38
# 534     We Own the Night  Drama            55              63              21
# 541             Whip It   Drama            84              73              15
# 545        Winter's Bone  Drama            94              73               2
#
#      Year
# 10   2007
# ...

# %%
movies[movies.Genre == 'Drama'].BudgetMillions   #o que está escrito de movies até Drama é um novo data frame. 
                                                #Adiciono o pontoBudgetMillions com o mesmo raciocínio 
                                                #lógico de movies.BudgetMillions
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
#Finalmente, aplico o filtro

plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins=15)
plt.show()

# %%
#posso adicionar vários tipos de filmes no mesmo gráfico

plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins=15)

plt.show()

# %%
#este gráfico não é a versão pretendida. Queremos as barras umas por cima das outras

plt.hist([movies[movies.Genre == 'Action'].BudgetMillions, \
          movies[movies.Genre == 'Drama'].BudgetMillions], bins=15, stacked=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#isto foram só com 2 tipos de filmes... o que fazer se tivesse 100 tipos diferentes??

#temos de iterate o Genre -- criar um loop

for gen in movies.Genre.cat.categories:     #vai iteragir sobre a lista de categorias de filmes
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
#segundo passo: precisamos da lista do plt gráfico de histograma. 
#Nós queremos que o loop crie essa lista por nós em vez de adicionarmos várias linhas manualmente

list1 = list()  #criar uma lista vazia
for gen in movies.Genre.cat.categories:     
    list1.append(movies[movies.Genre == gen].BudgetMillions)  #appending the series, ou seja, adicionar algo do lado direito da lista
print(list1)
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
#       ...
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: BudgetMillions, Length: 154, dtype: int64, 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# 167    250
# 168    150
# 176     36
# 178    150
# 192     70
# 193     60
# 241     60
# 272     37
# 341     19
# 363     70
# 386    130
# 401    155
# 459     59
# 463     25
# 506     38
# 540    100
# 548     60
# Name: BudgetMillions, dtype: int64, 0       8
# 4      20
# 6      30
# 8      28
# 9       8
#        ..
# 552    80
# 553    22
# 554    50
# 555    18
# 558    80
# Name: BudgetMillions, Length: 172, dtype: int64, 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64, 7      32
# 12     35
# ...

# %%
list1 = list()  #criar uma lista vazia
mylabels = list()
for gen in movies.Genre.cat.categories:     
    list1.append(movies[movies.Genre == gen].BudgetMillions)  #appending the series, ou seja, adicionar algo do lado direito da lista
    mylabels.append(gen)

h = plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %%
#KDE Plot - Kernel Density Estimate Plot

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', \
                 fit_reg=False, hue='Genre', \
                 size=7, aspect=1)

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating)

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                 shade=True, shade_lowest=False, cmap='Reds')

k2 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                 cmap='Reds')

# %% [markdown]
# ---

# %%
#Working with subplots

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)   #se o orçamento influencia as críticas da audiência

# %%
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
#Violin Plots

# %%
#z = sns.violinplot(data=movies, x='Genre', y='CriticRating')

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
#w = sns.boxplot(data=movies, x='Genre', y='CriticRating')

w = sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %% [markdown]
# ---

# %%
#Creating Facet Grid

# %%
g = sns.FacetGrid(movies, row='Genre', hue='Genre')

# %% [markdown]
# ---

# %%
#Building Dashboards

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
f, axes = plt.subplots(2,2, figsize=(15,15))

# %% [markdown]
# ---

# %%
#Thematic Edits

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:     
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)

sns.set_style("whitegrid")
fig, ax = plt.subplots()   #fazemos isto para nos permitir mexer no tamanho do gráfico livremente
fig.set_size_inches(11.7,8.27)  #size of an A4
h = plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)
plt.title("Movie Budget Distribution", fontsize=35, color='DarkBlue', fontname="Console")
plt.ylabel("Number of Movies", fontsize=25, color="Red")
plt.xlabel("Budget", fontsize=25, color="Green")
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.legend(frameon=True,fancybox=True,shadow=True, framealpha=1, prop={'size':20})
plt.show()
